# %% [markdown]
# ## Atrificial Intelligence Using Python Digi Skill Course: ##
# Mean propuse of this course
# Focus:
# Goal is to help you to understand AI, develope the confidance in job and freelancing work.
#
# ## What is AI?
# AI refers to enabling machines to perform tasks that can be carried out by human beings.
# * Copying human intrlligence
# * Learn with examples
#   Such as learning from data, recognzing patterns, asking decisions and improving over time.
#
# ## Why AI is important Today?
# * Automation  --Automates repetitive and complex tasks
# * Beter Decision Making  --Finds patterns humans miss
# * New opportunities  --New careers: Data Analyst, ML Engineer
#
# ### Punch Line:
#
# "AI does not replace humans it enhances human Capability."
#
#
# ## Python:
#
# "Python is the language that allows us to communicate our ideas to machines."
#
#
# Before AI can work, data must be cleaned understood, and analyzed this is where data science begins.
#
# ## Machine Learning:
# * Supervised learning means learning with correct answers provided.
# * Unsupervised learning means discovering hidden patterns independently.
# * Reinforcement learning means receiving feedback only on whether the output is correct and incorrect.
#
# ## Deep Learning:
#  Deep learning as an advanced form of ML inspired by the human brain.
