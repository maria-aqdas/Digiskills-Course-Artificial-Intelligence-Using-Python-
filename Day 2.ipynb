# %% [markdown]
# ## MYTHs about AI:
#
# * AI will replace human jobs but "Reality" is AI creates new roles and enhances human work. It remove humans from harsh labour and hazardous conditions.
# * AI make perfect decisions.
# * AI can solve any problem.
# * Needs massive computing power
#
# ## Truth about AI
#
# * "Tools to assist not replace."
# * "Limited by data and human guidance"
# * "accessible with todays's resources
#
# ## Why python is a good language for AI?
#
# * Accomplishes many tasks with minimal code
# * rich labrary support
# * simple and easy to learn syntax
# * interpreted languaugge
# * widely used across multiple industries
# * quick prototyping or poc
# * strong community support
# * high versatile, used in data science, machine learning, web development and scripting

# %%
print("Allah Alimighty")
print("Holy Prophet Hazart Muhammad (SAW)")
print("My love is Allah and alwasy he is in my heart, i am nothing without him. He is my all asserts and my most expensive thing. I sacrifice my self and all my thing for Allah and prophet MUhammad (SAW). MAY ALLAH GIVE STRENGTH IN MY LOVE!!!")
# Out:
# Allah Alimighty
# Holy Prophet Hazart Muhammad (SAW)
# My love is Allah and alwasy he is in my heart, i am nothing without him. He is my all asserts and my most expensive thing. I sacrifice my self and all my thing for Allah and prophet MUhammad (SAW). MAY ALLAH GIVE STRENGTH IN MY LOVE!!!
